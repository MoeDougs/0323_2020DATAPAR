# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv('/Users/apple/desktop/diamonds_clean.csv')
diamonds = diamonds.drop('Unnamed: 0', axis=1)

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    clarity_new  color_new
# 0            1          5
# 1            2          5
# 2            4          5
# 3            3          1
# 4            1          0

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
diamonds.describe().round()
# Out:
#          carat    depth    table    price        x        y        z  \
# count  53932.0  53932.0  53932.0  53932.0  53932.0  53932.0  53932.0
# mean       1.0     62.0     57.0   3932.0      6.0      6.0      4.0
# std        0.0      1.0      2.0   3989.0      1.0      1.0      1.0
# min        0.0     43.0     43.0    326.0      4.0      4.0      0.0
# 25%        0.0     61.0     56.0    950.0      5.0      5.0      3.0
# 50%        1.0     62.0     57.0   2401.0      6.0      6.0      4.0
# 75%        1.0     62.0     59.0   5324.0      7.0      7.0      4.0
# max        5.0     79.0     95.0  18823.0     11.0     59.0      8.0
#
#        clarity_new  color_new
# count      53932.0    53932.0
# mean           3.0        3.0
# std            2.0        2.0
# min            0.0        0.0
# 25%            2.0        2.0
# 50%            3.0        3.0
# 75%            4.0        5.0
# max            7.0        6.0

# %%
#your comments here

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#your hypotheses here
#Clarity_new,color_new,carat

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here
diamonds.groupby('color').agg('mean')
# Out:
#           carat      depth      table        price         x         y  \
# color
# D      0.657715  61.698066  57.404355  3168.106436  5.417851  5.421928
# E      0.657867  61.662090  57.491201  3076.752475  5.411580  5.419029
# F      0.736509  61.694087  57.433148  3725.091938  5.616727  5.620529
# G      0.771088  61.757449  57.288060  3998.145173  5.678549  5.681198
# H      0.911627  61.836557  57.518176  4484.958805  5.984776  5.986256
# I      1.026927  61.846385  57.577278  5091.874954  6.222826  6.222730
# J      1.162137  61.887215  57.812393  5323.818020  6.519338  6.518105
#
#               z  clarity_new  color_new
# color
# D      3.343320     2.691025        6.0
# E      3.337443     2.969889        5.0
# F      3.465938     3.134605        4.0
# G      3.507966     3.463419        3.0
# H      3.699147     2.933871        2.0
# I      3.846368     2.964035        1.0
# J      4.033251     2.776353        0.0

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#your thoughts here
'As color gets better, average prices are decreasing'
# Out:
# 'As color gets better, average prices are decreasing'

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here
diamonds.color.value_counts().plot(kind='bar')
plt.xlabel('Diamond Colors')
plt.ylabel('Frequency')
plt.title('DC Freq');

# %%
#your comments here
'I think the frequency distribution justified the awkward relationship between prices and color'
# Out:
# 'I think the frequency distribution justified the awkward relationship between prices and color'

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.groupby('carat').agg('mean').round(2)
# Out:
#        depth  table     price      x      y     z  clarity_new  color_new  \
# carat
# 0.20   61.10  59.33    365.17   3.79   3.75  2.30         2.83       5.17
# 0.21   60.51  58.44    380.22   3.87   3.84  2.33         2.67       5.44
# 0.22   61.62  60.40    391.40   3.90   3.85  2.39         2.60       4.80
# 0.23   61.43  58.03    486.14   3.95   3.97  2.43         4.90       4.52
# 0.24   61.60  57.49    505.19   3.99   4.02  2.47         4.97       4.19
# ...      ...    ...       ...    ...    ...   ...          ...        ...
# 4.00   63.30  58.00  15984.00  10.01   9.94  6.31         0.00       1.00
# 4.01   61.75  61.50  15223.00  10.08   9.97  6.20         0.00       0.50
# 4.13   64.80  61.00  17329.00  10.00   9.85  6.43         0.00       2.00
# 4.50   65.80  58.00  18531.00  10.23  10.00  6.72         0.00       0.00
# 5.01   65.50  59.00  18018.00  10.74  11.00  6.98         0.00       0.00
#
#        validate_z
# carat
# 0.20        61.10
# 0.21        60.51
# 0.22        61.62
# 0.23        61.42
# 0.24        61.58
# ...           ...
# 4.00        63.30
# 4.01        61.75
# 4.13        64.80
# 4.50        65.90
# 5.01        65.60
#
# [273 rows x 9 columns]

# %%
#your comments
'As carat weight increases, prices increase'

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#your code here
diamonds.carat.hist(bins=100,color='r')
plt.xlabel('Diamond Carat')
plt.ylabel('Frequency')
plt.title('Carat Freq');

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.groupby('table').agg('mean').round(2)
# Out:
#        carat  depth    price     x     y     z  clarity_new  color_new  \
# table
# 43.0    1.04  62.90   4997.0  6.45  6.41  4.04         4.00        1.0
# 44.0    0.29  62.80    474.0  4.20  4.24  2.65         4.00        5.0
# 49.0    0.65  64.25   2290.5  5.36  5.32  3.42         3.00        3.0
# 50.0    1.51  61.50   8995.5  7.38  7.30  4.51         2.00        3.0
# 50.1    0.94  66.00   3353.0  6.13  6.17  4.06         1.00        2.0
# ...      ...    ...      ...   ...   ...   ...          ...        ...
# 71.0    0.68  58.00   1633.0  5.85  5.70  3.35         2.00        3.0
# 73.0    0.60  68.90   2406.5  5.52  5.46  3.74         3.25        4.5
# 76.0    0.79  65.30   2362.0  5.52  5.13  3.35         2.00        3.0
# 79.0    0.81  68.80   2301.0  5.26  5.20  3.58         1.00        4.0
# 95.0    2.01  58.60  13387.0  8.32  8.31  4.87         2.00        4.0
#
#        validate_z
# table
# 43.0        62.80
# 44.0        62.80
# 49.0        64.25
# 50.0        61.50
# 50.1        66.00
# ...           ...
# 71.0        58.00
# 73.0        68.75
# 76.0        62.90
# 79.0        68.50
# 95.0        58.60
#
# [127 rows x 9 columns]

# %%
#your comments here
'There is no clear relationship between table and price '

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here
diamonds.groupby('clarity_new').agg('mean').round(2)
# Out:
#              carat  depth  table    price     x     y     z  color_new  \
# clarity_new
# 0             1.28  62.73  58.30  3924.17  6.76  6.71  4.22       2.97
# 1             1.08  61.77  57.93  5062.27  6.40  6.40  3.95       3.47
# 2             0.85  61.85  57.66  3996.00  5.89  5.89  3.64       3.45
# 3             0.76  61.72  57.42  3924.17  5.66  5.66  3.49       3.49
# 4             0.73  61.67  57.31  3839.14  5.57  5.58  3.44       3.16
# 5             0.60  61.66  57.02  3283.74  5.22  5.23  3.22       3.57
# 6             0.50  61.62  56.88  2519.51  4.96  4.98  3.06       3.35
# 7             0.51  61.51  56.51  2864.84  4.97  4.99  3.06       3.10
#
#              validate_z
# clarity_new
# 0                 62.75
# 1                 61.78
# 2                 61.85
# 3                 61.73
# 4                 61.73
# 5                 61.66
# 6                 61.63
# 7                 61.50

# %%
#your comments here
'Similar relationship to the color, where the better the clarity is the lower the average price'

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here
'Carat seems the most prominent feature in determining the price of diamond'

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %%
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %%
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here
'Some of the relationships clearly match between the heat map and the pairplot such as the corrolation between carat and price'

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)

# %%
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8493658995804622

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here
'This is a good number meaning that 85% of total variation in Y can be explained by a linear relationship between X and Y  '

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here
'I would check r to see if they are positively or negatively correlated'

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
