# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# #### Import data set.
#
# Import data set `Pokemon` from Ironhack's database. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set from Ironhack's database
df=pd.read_csv('/Users/apple/desktop/Daily Exercises/Pokemon.csv')

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# your code here
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
df.rename(columns={"Type 1":'t1','Type 2':'t2'},inplace=True)

# %%
# your code here
t1=[i for i in df.t1.unique()]
t2=[i for i in df.t2.unique()]

t3=set(t1+t2)
t3
# Out:
# {'Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water',
#  nan}

# %%
x=df[['t1','t2']].apply(lambda x: set((x.t1,x.t2)), axis=1).values
x
# Out:
# array([{'Poison', 'Grass'}, {'Poison', 'Grass'}, {'Poison', 'Grass'},
#        {'Poison', 'Grass'}, {'Fire', nan}, {'Fire', nan},
#        {'Fire', 'Flying'}, {'Fire', 'Dragon'}, {'Fire', 'Flying'},
#        {nan, 'Water'}, {nan, 'Water'}, {nan, 'Water'}, {nan, 'Water'},
#        {nan, 'Bug'}, {nan, 'Bug'}, {'Bug', 'Flying'}, {'Bug', 'Poison'},
#        {'Bug', 'Poison'}, {'Bug', 'Poison'}, {'Bug', 'Poison'},
#        {'Normal', 'Flying'}, {'Normal', 'Flying'}, {'Normal', 'Flying'},
#        {'Normal', 'Flying'}, {nan, 'Normal'}, {nan, 'Normal'},
#        {'Normal', 'Flying'}, {'Normal', 'Flying'}, {nan, 'Poison'},
#        {nan, 'Poison'}, {nan, 'Electric'}, {nan, 'Electric'},
#        {nan, 'Ground'}, {nan, 'Ground'}, {nan, 'Poison'}, {nan, 'Poison'},
#        {'Poison', 'Ground'}, {nan, 'Poison'}, {nan, 'Poison'},
#        {'Poison', 'Ground'}, {nan, 'Fairy'}, {nan, 'Fairy'},
#        {'Fire', nan}, {'Fire', nan}, {'Fairy', 'Normal'},
#        {'Fairy', 'Normal'}, {'Poison', 'Flying'}, {'Poison', 'Flying'},
#        {'Poison', 'Grass'}, {'Poison', 'Grass'}, {'Poison', 'Grass'},
#        {'Bug', 'Grass'}, {'Bug', 'Grass'}, {'Bug', 'Poison'},
#        {'Bug', 'Poison'}, {nan, 'Ground'}, {nan, 'Ground'},
#        {nan, 'Normal'}, {nan, 'Normal'}, {nan, 'Water'}, {nan, 'Water'},
#        {nan, 'Fighting'}, {nan, 'Fighting'}, {'Fire', nan}, {'Fire', nan},
#        {nan, 'Water'}, {nan, 'Water'}, {'Water', 'Fighting'},
#        {nan, 'Psychic'}, {nan, 'Psychic'}, {nan, 'Psychic'},
#        {nan, 'Psychic'}, {nan, 'Fighting'}, {nan, 'Fighting'},
#        {nan, 'Fighting'}, {'Poison', 'Grass'}, {'Poison', 'Grass'},
#        {'Poison', 'Grass'}, {'Poison', 'Water'}, {'Poison', 'Water'},
#        {'Ground', 'Rock'}, {'Ground', 'Rock'}, {'Ground', 'Rock'},
#        {'Fire', nan}, {'Fire', nan}, {'Water', 'Psychic'},
#        {'Water', 'Psychic'}, {'Water', 'Psychic'}, {'Steel', 'Electric'},
#        {'Steel', 'Electric'}, {'Normal', 'Flying'}, {'Normal', 'Flying'},
#        {'Normal', 'Flying'}, {nan, 'Water'}, {'Ice', 'Water'},
#        {nan, 'Poison'}, {nan, 'Poison'}, {nan, 'Water'}, {'Ice', 'Water'},
#        {'Poison', 'Ghost'}, {'Poison', 'Ghost'}, {'Poison', 'Ghost'},
#        {'Poison', 'Ghost'}, {'Ground', 'Rock'}, {nan, 'Psychic'},
#        {nan, 'Psychic'}, {nan, 'Water'}, {nan, 'Water'},
#        {nan, 'Electric'}, {nan, 'Electric'}, {'Grass', 'Psychic'},
#        {'Grass', 'Psychic'}, {nan, 'Ground'}, {nan, 'Ground'},
#        {nan, 'Fighting'}, {nan, 'Fighting'}, {nan, 'Normal'},
#        {nan, 'Poison'}, {nan, 'Poison'}, {'Ground', 'Rock'},
#        {'Ground', 'Rock'}, {nan, 'Normal'}, {nan, 'Grass'},
#        {nan, 'Normal'}, {nan, 'Normal'}, {nan, 'Water'}, {nan, 'Water'},
#        {nan, 'Water'}, {nan, 'Water'}, {nan, 'Water'},
#        {'Water', 'Psychic'}, {'Fairy', 'Psychic'}, {'Bug', 'Flying'},
#        {'Ice', 'Psychic'}, {nan, 'Electric'}, {'Fire', nan}, {nan, 'Bug'},
#        {'Bug', 'Flying'}, {nan, 'Normal'}, {nan, 'Water'},
#        {'Water', 'Flying'}, {'Dark', 'Water'}, {'Ice', 'Water'},
#        {nan, 'Normal'}, {nan, 'Normal'}, {nan, 'Water'},
#        {nan, 'Electric'}, {'Fire', nan}, {nan, 'Normal'},
#        {'Rock', 'Water'}, {'Rock', 'Water'}, {'Rock', 'Water'},
#        {'Rock', 'Water'}, {'Rock', 'Flying'}, {'Rock', 'Flying'},
#        {nan, 'Normal'}, {'Ice', 'Flying'}, {'Electric', 'Flying'},
#        {'Fire', 'Flying'}, {nan, 'Dragon'}, {nan, 'Dragon'},
#        {'Flying', 'Dragon'}, {nan, 'Psychic'}, {'Fighting', 'Psychic'},
#        {nan, 'Psychic'}, {nan, 'Psychic'}, {nan, 'Grass'}, {nan, 'Grass'},
#        {nan, 'Grass'}, {'Fire', nan}, {'Fire', nan}, {'Fire', nan},
#        {nan, 'Water'}, {nan, 'Water'}, {nan, 'Water'}, {nan, 'Normal'},
#        {nan, 'Normal'}, {'Normal', 'Flying'}, {'Normal', 'Flying'},
#        {'Bug', 'Flying'}, {'Bug', 'Flying'}, {'Bug', 'Poison'},
#        {'Bug', 'Poison'}, {'Poison', 'Flying'}, {'Electric', 'Water'},
#        {'Electric', 'Water'}, {nan, 'Electric'}, {nan, 'Fairy'},
#        {'Fairy', 'Normal'}, {nan, 'Fairy'}, {'Fairy', 'Flying'},
#        {'Psychic', 'Flying'}, {'Psychic', 'Flying'}, {nan, 'Electric'},
#        {nan, 'Electric'}, {nan, 'Electric'}, {'Electric', 'Dragon'},
#        {nan, 'Grass'}, {'Fairy', 'Water'}, {'Fairy', 'Water'},
#        {nan, 'Rock'}, {nan, 'Water'}, {'Grass', 'Flying'},
#        {'Grass', 'Flying'}, {'Grass', 'Flying'}, {nan, 'Normal'},
#        {nan, 'Grass'}, {nan, 'Grass'}, {'Bug', 'Flying'},
#        {'Ground', 'Water'}, {'Ground', 'Water'}, {nan, 'Psychic'},
#        {nan, 'Dark'}, {'Dark', 'Flying'}, {'Water', 'Psychic'},
#        {nan, 'Ghost'}, {nan, 'Psychic'}, {nan, 'Psychic'},
#        {'Normal', 'Psychic'}, {nan, 'Bug'}, {'Bug', 'Steel'},
#        {nan, 'Normal'}, {'Ground', 'Flying'}, {'Steel', 'Ground'},
#        {'Steel', 'Ground'}, {nan, 'Fairy'}, {nan, 'Fairy'},
#        {'Poison', 'Water'}, {'Bug', 'Steel'}, {'Bug', 'Steel'},
#        {'Bug', 'Rock'}, {'Bug', 'Fighting'}, {'Bug', 'Fighting'},
#        {'Dark', 'Ice'}, {nan, 'Normal'}, {nan, 'Normal'}, {'Fire', nan},
#        {'Fire', 'Rock'}, {'Ground', 'Ice'}, {'Ground', 'Ice'},
#        {'Water', 'Rock'}, {nan, 'Water'}, {nan, 'Water'},
#        {'Ice', 'Flying'}, {'Water', 'Flying'}, {'Steel', 'Flying'},
#        {'Fire', 'Dark'}, {'Fire', 'Dark'}, {'Fire', 'Dark'},
#        {'Water', 'Dragon'}, {nan, 'Ground'}, {nan, 'Ground'},
#        {nan, 'Normal'}, {nan, 'Normal'}, {nan, 'Normal'},
#        {nan, 'Fighting'}, {nan, 'Fighting'}, {'Ice', 'Psychic'},
#        {nan, 'Electric'}, {'Fire', nan}, {nan, 'Normal'}, {nan, 'Normal'},
#        {nan, 'Electric'}, {'Fire', nan}, {nan, 'Water'},
#        {'Ground', 'Rock'}, {'Ground', 'Rock'}, {'Dark', 'Rock'},
#        {'Dark', 'Rock'}, {'Psychic', 'Flying'}, {'Fire', 'Flying'},
#        {'Grass', 'Psychic'}, {nan, 'Grass'}, {nan, 'Grass'},
#        {nan, 'Grass'}, {'Grass', 'Dragon'}, {'Fire', nan},
#        {'Fire', 'Fighting'}, {'Fire', 'Fighting'}, {'Fire', 'Fighting'},
#        {nan, 'Water'}, {'Ground', 'Water'}, {'Ground', 'Water'},
#        {'Ground', 'Water'}, {nan, 'Dark'}, {nan, 'Dark'}, {nan, 'Normal'},
#        {nan, 'Normal'}, {nan, 'Bug'}, {nan, 'Bug'}, {'Bug', 'Flying'},
#        {nan, 'Bug'}, {'Bug', 'Poison'}, {'Grass', 'Water'},
#        {'Grass', 'Water'}, {'Grass', 'Water'}, {nan, 'Grass'},
#        {'Dark', 'Grass'}, {'Dark', 'Grass'}, {'Normal', 'Flying'},
#        {'Normal', 'Flying'}, {'Water', 'Flying'}, {'Water', 'Flying'},
#        {'Fairy', 'Psychic'}, {'Fairy', 'Psychic'}, {'Fairy', 'Psychic'},
#        {'Fairy', 'Psychic'}, {'Bug', 'Water'}, {'Bug', 'Flying'},
#        {nan, 'Grass'}, {'Grass', 'Fighting'}, {nan, 'Normal'},
#        {nan, 'Normal'}, {nan, 'Normal'}, {'Bug', 'Ground'},
#        {'Bug', 'Flying'}, {'Bug', 'Ghost'}, {nan, 'Normal'},
#        {nan, 'Normal'}, {nan, 'Normal'}, {nan, 'Fighting'},
#        {nan, 'Fighting'}, {'Fairy', 'Normal'}, {nan, 'Rock'},
#        {nan, 'Normal'}, {nan, 'Normal'}, {'Dark', 'Ghost'},
#        {'Dark', 'Ghost'}, {'Steel', 'Fairy'}, {'Steel', 'Fairy'},
#        {'Steel', 'Rock'}, {'Steel', 'Rock'}, {'Steel', 'Rock'},
#        {nan, 'Steel'}, {'Fighting', 'Psychic'}, {'Fighting', 'Psychic'},
#        {'Fighting', 'Psychic'}, {nan, 'Electric'}, {nan, 'Electric'},
#        {nan, 'Electric'}, {nan, 'Electric'}, {nan, 'Electric'},
#        {nan, 'Bug'}, {nan, 'Bug'}, {'Poison', 'Grass'}, {nan, 'Poison'},
#        {nan, 'Poison'}, {'Dark', 'Water'}, {'Dark', 'Water'},
#        {'Dark', 'Water'}, {nan, 'Water'}, {nan, 'Water'},
#        {'Fire', 'Ground'}, {'Fire', 'Ground'}, {'Fire', 'Ground'},
#        {'Fire', nan}, {nan, 'Psychic'}, {nan, 'Psychic'}, {nan, 'Normal'},
#        {nan, 'Ground'}, {'Ground', 'Dragon'}, {'Ground', 'Dragon'},
#        {nan, 'Grass'}, {'Dark', 'Grass'}, {'Normal', 'Flying'},
#        {'Flying', 'Dragon'}, {'Fairy', 'Dragon'}, {nan, 'Normal'},
#        {nan, 'Poison'}, {'Rock', 'Psychic'}, {'Rock', 'Psychic'},
#        {'Ground', 'Water'}, {'Ground', 'Water'}, {nan, 'Water'},
#        {'Dark', 'Water'}, {'Ground', 'Psychic'}, {'Ground', 'Psychic'},
#        {'Grass', 'Rock'}, {'Grass', 'Rock'}, {'Bug', 'Rock'},
#        {'Bug', 'Rock'}, {nan, 'Water'}, {nan, 'Water'}, {nan, 'Normal'},
#        {nan, 'Normal'}, {nan, 'Ghost'}, {nan, 'Ghost'}, {nan, 'Ghost'},
#        {nan, 'Ghost'}, {nan, 'Ghost'}, {'Grass', 'Flying'},
#        {nan, 'Psychic'}, {nan, 'Dark'}, {nan, 'Dark'}, {nan, 'Psychic'},
#        {nan, 'Ice'}, {nan, 'Ice'}, {nan, 'Ice'}, {'Ice', 'Water'},
#        {'Ice', 'Water'}, {'Ice', 'Water'}, {nan, 'Water'}, {nan, 'Water'},
#        {nan, 'Water'}, {'Water', 'Rock'}, {nan, 'Water'}, {nan, 'Dragon'},
#        {nan, 'Dragon'}, {'Flying', 'Dragon'}, {'Flying', 'Dragon'},
#        {'Steel', 'Psychic'}, {'Steel', 'Psychic'}, {'Steel', 'Psychic'},
#        {'Steel', 'Psychic'}, {nan, 'Rock'}, {nan, 'Ice'}, {nan, 'Steel'},
#        {'Psychic', 'Dragon'}, {'Psychic', 'Dragon'},
#        {'Psychic', 'Dragon'}, {'Psychic', 'Dragon'}, {nan, 'Water'},
#        {nan, 'Water'}, {nan, 'Ground'}, {'Fire', 'Ground'},
#        {'Flying', 'Dragon'}, {'Flying', 'Dragon'}, {'Steel', 'Psychic'},
#        {nan, 'Psychic'}, {nan, 'Psychic'}, {nan, 'Psychic'},
#        {nan, 'Psychic'}, {nan, 'Grass'}, {nan, 'Grass'},
#        {'Grass', 'Ground'}, {'Fire', nan}, {'Fire', 'Fighting'},
#        {'Fire', 'Fighting'}, {nan, 'Water'}, {nan, 'Water'},
#        {'Steel', 'Water'}, {'Normal', 'Flying'}, {'Normal', 'Flying'},
#        {'Normal', 'Flying'}, {nan, 'Normal'}, {'Normal', 'Water'},
#        {nan, 'Bug'}, {nan, 'Bug'}, {nan, 'Electric'}, {nan, 'Electric'},
#        {nan, 'Electric'}, {'Poison', 'Grass'}, {'Poison', 'Grass'},
#        {nan, 'Rock'}, {nan, 'Rock'}, {'Steel', 'Rock'}, {'Steel', 'Rock'},
#        {nan, 'Bug'}, {'Bug', 'Grass'}, {'Bug', 'Ground'},
#        {'Bug', 'Steel'}, {'Bug', 'Flying'}, {'Bug', 'Flying'},
#        {'Bug', 'Flying'}, {nan, 'Electric'}, {nan, 'Water'},
#        {nan, 'Water'}, {nan, 'Grass'}, {nan, 'Grass'}, {nan, 'Water'},
#        {'Ground', 'Water'}, {nan, 'Normal'}, {'Ghost', 'Flying'},
#        {'Ghost', 'Flying'}, {nan, 'Normal'}, {nan, 'Normal'},
#        {'Normal', 'Fighting'}, {nan, 'Ghost'}, {'Dark', 'Flying'},
#        {nan, 'Normal'}, {nan, 'Normal'}, {nan, 'Psychic'},
#        {'Dark', 'Poison'}, {'Dark', 'Poison'}, {'Steel', 'Psychic'},
#        {'Steel', 'Psychic'}, {nan, 'Rock'}, {'Fairy', 'Psychic'},
#        {nan, 'Normal'}, {'Normal', 'Flying'}, {'Dark', 'Ghost'},
#        {'Ground', 'Dragon'}, {'Ground', 'Dragon'}, {'Ground', 'Dragon'},
#        {'Ground', 'Dragon'}, {nan, 'Normal'}, {nan, 'Fighting'},
#        {'Steel', 'Fighting'}, {'Steel', 'Fighting'}, {nan, 'Ground'},
#        {nan, 'Ground'}, {'Bug', 'Poison'}, {'Dark', 'Poison'},
#        {'Poison', 'Fighting'}, {'Poison', 'Fighting'}, {nan, 'Grass'},
#        {nan, 'Water'}, {nan, 'Water'}, {'Water', 'Flying'},
#        {'Grass', 'Ice'}, {'Grass', 'Ice'}, {'Grass', 'Ice'},
#        {'Dark', 'Ice'}, {'Steel', 'Electric'}, {nan, 'Normal'},
#        {'Ground', 'Rock'}, {nan, 'Grass'}, {nan, 'Electric'},
#        {'Fire', nan}, {'Fairy', 'Flying'}, {'Bug', 'Flying'},
#        {nan, 'Grass'}, {nan, 'Ice'}, {'Ground', 'Flying'},
#        {'Ground', 'Ice'}, {nan, 'Normal'}, {'Fighting', 'Psychic'},
#        {'Fighting', 'Psychic'}, {'Steel', 'Rock'}, {nan, 'Ghost'},
#        {'Ghost', 'Ice'}, {'Electric', 'Ghost'}, {'Fire', 'Electric'},
#        {'Electric', 'Water'}, {'Electric', 'Ice'}, {'Electric', 'Flying'},
#        {'Grass', 'Electric'}, {nan, 'Psychic'}, {nan, 'Psychic'},
#        {nan, 'Psychic'}, {'Steel', 'Dragon'}, {'Water', 'Dragon'},
#        {'Fire', 'Steel'}, {nan, 'Normal'}, {'Ghost', 'Dragon'},
#        {'Ghost', 'Dragon'}, {nan, 'Psychic'}, {nan, 'Water'},
#        {nan, 'Water'}, {nan, 'Dark'}, {nan, 'Grass'}, {'Grass', 'Flying'},
#        {nan, 'Normal'}, {'Fire', 'Psychic'}, {nan, 'Grass'},
#        {nan, 'Grass'}, {nan, 'Grass'}, {'Fire', nan},
#        {'Fire', 'Fighting'}, {'Fire', 'Fighting'}, {nan, 'Water'},
#        {nan, 'Water'}, {nan, 'Water'}, {nan, 'Normal'}, {nan, 'Normal'},
#        {nan, 'Normal'}, {nan, 'Normal'}, {nan, 'Normal'}, {nan, 'Dark'},
#        {nan, 'Dark'}, {nan, 'Grass'}, {nan, 'Grass'}, {'Fire', nan},
#        {'Fire', nan}, {nan, 'Water'}, {nan, 'Water'}, {nan, 'Psychic'},
#        {nan, 'Psychic'}, {'Normal', 'Flying'}, {'Normal', 'Flying'},
#        {'Normal', 'Flying'}, {nan, 'Electric'}, {nan, 'Electric'},
#        {nan, 'Rock'}, {nan, 'Rock'}, {nan, 'Rock'}, {'Psychic', 'Flying'},
#        {'Psychic', 'Flying'}, {nan, 'Ground'}, {'Steel', 'Ground'},
#        {nan, 'Normal'}, {'Fairy', 'Normal'}, {nan, 'Fighting'},
#        {nan, 'Fighting'}, {nan, 'Fighting'}, {nan, 'Water'},
#        {'Ground', 'Water'}, {'Ground', 'Water'}, {nan, 'Fighting'},
#        {nan, 'Fighting'}, {'Bug', 'Grass'}, {'Bug', 'Grass'},
#        {'Bug', 'Grass'}, {'Bug', 'Poison'}, {'Bug', 'Poison'},
#        {'Bug', 'Poison'}, {'Grass', 'Fairy'}, {'Grass', 'Fairy'},
#        {nan, 'Grass'}, {nan, 'Grass'}, {nan, 'Water'}, {'Dark', 'Ground'},
#        {'Dark', 'Ground'}, {'Dark', 'Ground'}, {'Fire', nan},
#        {'Fire', nan}, {'Fire', 'Psychic'}, {nan, 'Grass'},
#        {'Bug', 'Rock'}, {'Bug', 'Rock'}, {'Dark', 'Fighting'},
#        {'Dark', 'Fighting'}, {'Psychic', 'Flying'}, {nan, 'Ghost'},
#        {nan, 'Ghost'}, {'Water', 'Rock'}, {'Water', 'Rock'},
#        {'Rock', 'Flying'}, {'Rock', 'Flying'}, {nan, 'Poison'},
#        {nan, 'Poison'}, {nan, 'Dark'}, {nan, 'Dark'}, {nan, 'Normal'},
#        {nan, 'Normal'}, {nan, 'Psychic'}, {nan, 'Psychic'},
#        {nan, 'Psychic'}, {nan, 'Psychic'}, {nan, 'Psychic'},
#        {nan, 'Psychic'}, {'Water', 'Flying'}, {'Water', 'Flying'},
#        {nan, 'Ice'}, {nan, 'Ice'}, {nan, 'Ice'}, {'Grass', 'Normal'},
#        {'Grass', 'Normal'}, {'Electric', 'Flying'}, {nan, 'Bug'},
#        {'Bug', 'Steel'}, {'Poison', 'Grass'}, {'Poison', 'Grass'},
#        {'Ghost', 'Water'}, {'Ghost', 'Water'}, {nan, 'Water'},
#        {'Bug', 'Electric'}, {'Bug', 'Electric'}, {'Steel', 'Grass'},
#        {'Steel', 'Grass'}, {nan, 'Steel'}, {nan, 'Steel'}, {nan, 'Steel'},
#        {nan, 'Electric'}, {nan, 'Electric'}, {nan, 'Electric'},
#        {nan, 'Psychic'}, {nan, 'Psychic'}, {'Fire', 'Ghost'},
#        {'Fire', 'Ghost'}, {'Fire', 'Ghost'}, {nan, 'Dragon'},
#        {nan, 'Dragon'}, {nan, 'Dragon'}, {nan, 'Ice'}, {nan, 'Ice'},
#        {nan, 'Ice'}, {nan, 'Bug'}, {nan, 'Bug'}, {'Electric', 'Ground'},
#        {nan, 'Fighting'}, {nan, 'Fighting'}, {nan, 'Dragon'},
#        {'Ground', 'Ghost'}, {'Ground', 'Ghost'}, {'Dark', 'Steel'},
#        {'Dark', 'Steel'}, {nan, 'Normal'}, {'Normal', 'Flying'},
#        {'Normal', 'Flying'}, {'Dark', 'Flying'}, {'Dark', 'Flying'},
#        {'Fire', nan}, {'Bug', 'Steel'}, {'Dark', 'Dragon'},
#        {'Dark', 'Dragon'}, {'Dark', 'Dragon'}, {'Fire', 'Bug'},
#        {'Fire', 'Bug'}, {'Steel', 'Fighting'}, {'Rock', 'Fighting'},
#        {'Grass', 'Fighting'}, {nan, 'Flying'}, {nan, 'Flying'},
#        {'Electric', 'Flying'}, {'Electric', 'Flying'}, {'Fire', 'Dragon'},
#        {'Electric', 'Dragon'}, {'Ground', 'Flying'}, {'Ground', 'Flying'},
#        {'Ice', 'Dragon'}, {'Ice', 'Dragon'}, {'Ice', 'Dragon'},
#        {'Water', 'Fighting'}, {'Water', 'Fighting'},
#        {'Normal', 'Psychic'}, {'Normal', 'Fighting'}, {'Bug', 'Steel'},
#        {nan, 'Grass'}, {nan, 'Grass'}, {'Grass', 'Fighting'},
#        {'Fire', nan}, {'Fire', nan}, {'Fire', 'Psychic'}, {nan, 'Water'},
#        {nan, 'Water'}, {'Dark', 'Water'}, {nan, 'Normal'},
#        {'Ground', 'Normal'}, {'Normal', 'Flying'}, {'Fire', 'Flying'},
#        {'Fire', 'Flying'}, {nan, 'Bug'}, {nan, 'Bug'}, {'Bug', 'Flying'},
#        {'Fire', 'Normal'}, {'Fire', 'Normal'}, {nan, 'Fairy'},
#        {nan, 'Fairy'}, {nan, 'Fairy'}, {nan, 'Grass'}, {nan, 'Grass'},
#        {nan, 'Fighting'}, {'Dark', 'Fighting'}, {nan, 'Normal'},
#        {nan, 'Psychic'}, {nan, 'Psychic'}, {nan, 'Psychic'},
#        {'Steel', 'Ghost'}, {'Steel', 'Ghost'}, {'Steel', 'Ghost'},
#        {'Steel', 'Ghost'}, {nan, 'Fairy'}, {nan, 'Fairy'}, {nan, 'Fairy'},
#        {nan, 'Fairy'}, {'Dark', 'Psychic'}, {'Dark', 'Psychic'},
#        {'Rock', 'Water'}, {'Rock', 'Water'}, {'Poison', 'Water'},
#        {'Poison', 'Dragon'}, {nan, 'Water'}, {nan, 'Water'},
#        {'Electric', 'Normal'}, {'Electric', 'Normal'}, {'Rock', 'Dragon'},
#        {'Rock', 'Dragon'}, {'Ice', 'Rock'}, {'Ice', 'Rock'},
#        {nan, 'Fairy'}, {'Fighting', 'Flying'}, {'Electric', 'Fairy'},
#        {'Fairy', 'Rock'}, {nan, 'Dragon'}, {nan, 'Dragon'},
#        {nan, 'Dragon'}, {'Steel', 'Fairy'}, {'Grass', 'Ghost'},
#        {'Grass', 'Ghost'}, {'Grass', 'Ghost'}, {'Grass', 'Ghost'},
#        {'Grass', 'Ghost'}, {'Grass', 'Ghost'}, {'Grass', 'Ghost'},
#        {'Grass', 'Ghost'}, {'Grass', 'Ghost'}, {'Grass', 'Ghost'},
#        {nan, 'Ice'}, {nan, 'Ice'}, {'Flying', 'Dragon'},
#        {'Flying', 'Dragon'}, {nan, 'Fairy'}, {'Dark', 'Flying'},
#        {'Ground', 'Dragon'}, {'Fairy', 'Rock'}, {'Fairy', 'Rock'},
#        {'Ghost', 'Psychic'}, {'Dark', 'Psychic'}, {'Fire', 'Water'}],
#       dtype=object)

# %%
set((df.t1.to_list())+(df.t2.to_list()))
# Out:
# {'Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water',
#  nan}

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
df.Name.str.replace('.*magic\b',)

# %%
df.Name=df.Name.map(lambda x: 'Mega'+x.split('Mega')[1] if 'Mega' in x else x)
df[0:15]
# Out:
#      #              Name     t1      t2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1    2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2    3          Venusaur  Grass  Poison    525  80      82       83      100
# 3    3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4    4        Charmander   Fire     NaN    309  39      52       43       60
# 5    5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6    6         Charizard   Fire  Flying    534  78      84       78      109
# 7    6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8    6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9    7          Squirtle  Water     NaN    314  44      48       65       50
# 10   8         Wartortle  Water     NaN    405  59      63       80       65
# 11   9         Blastoise  Water     NaN    530  79      83      100       85
# 12   9    Mega Blastoise  Water     NaN    630  79     103      120      135
# 13  10          Caterpie    Bug     NaN    195  45      30       35       20
# 14  11           Metapod    Bug     NaN    205  50      20       55       25
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 3       120     80           1      False
# 4        50     65           1      False
# 5        65     80           1      False
# 6        85    100           1      False
# 7        85    100           1      False
# 8       115    100           1      False
# 9        64     43           1      False
# 10       80     58           1      False
# 11      105     78           1      False
# 12      115     78           1      False
# 13       20     45           1      False
# 14       25     30           1      False

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here
df['A/D_Ratio']=round(df['Attack']/df['Defense'],2)
df
# Out:
#        #                 Name       t1      t2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318  45      49       49
# 1      2              Ivysaur    Grass  Poison    405  60      62       63
# 2      3             Venusaur    Grass  Poison    525  80      82       83
# 3      3        Mega Venusaur    Grass  Poison    625  80     100      123
# 4      4           Charmander     Fire     NaN    309  39      52       43
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 795  719              Diancie     Rock   Fairy    600  50     100      150
# 796  719         Mega Diancie     Rock   Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721            Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D_Ratio
# 0         65       65     45           1      False       1.00
# 1         80       80     60           1      False       0.98
# 2        100      100     80           1      False       0.99
# 3        122      120     80           1      False       0.81
# 4         60       50     65           1      False       1.21
# ..       ...      ...    ...         ...        ...        ...
# 795      100      150     50           6       True       0.67
# 796      160      110    110           6       True       1.45
# 797      150      130     70           6       True       1.83
# 798      170      130     80           6       True       2.67
# 799      130       90     70           6       True       0.92
#
# [800 rows x 14 columns]

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# your code here
df.loc[df['A/D_Ratio'].idxmax()]
# Out:
# #                            386
# Name          DeoxysAttack Forme
# t1                       Psychic
# t2                           NaN
# Total                        600
# HP                            50
# Attack                       180
# Defense                       20
# Sp. Atk                      180
# Sp. Def                       20
# Speed                        150
# Generation                     3
# Legendary                   True
# A/D_Ratio                      9
# Name: 429, dtype: object

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
# your code here
df.loc[df['A/D_Ratio'].idxmin()]
# Out:
# #                 213
# Name          Shuckle
# t1                Bug
# t2               Rock
# Total             505
# HP                 20
# Attack             10
# Defense           230
# Sp. Atk            10
# Sp. Def           230
# Speed               5
# Generation          2
# Legendary       False
# A/D_Ratio        0.04
# Name: 230, dtype: object

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
df['Combo_Type']=df[['t1','t2']].applymap(str).apply(lambda x: x.t1+'-'+x.t2 if ((x.t1!=np.nan) & (x.t2!=np.nan)) else x.t1, axis=1)
df
# Out:
#        #                 Name       t1      t2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318  45      49       49
# 1      2              Ivysaur    Grass  Poison    405  60      62       63
# 2      3             Venusaur    Grass  Poison    525  80      82       83
# 3      3        Mega Venusaur    Grass  Poison    625  80     100      123
# 4      4           Charmander     Fire     NaN    309  39      52       43
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 795  719              Diancie     Rock   Fairy    600  50     100      150
# 796  719         Mega Diancie     Rock   Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721            Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D_Ratio     Combo_Type
# 0         65       65     45           1      False       1.00   Grass-Poison
# 1         80       80     60           1      False       0.98   Grass-Poison
# 2        100      100     80           1      False       0.99   Grass-Poison
# 3        122      120     80           1      False       0.81   Grass-Poison
# 4         60       50     65           1      False       1.21       Fire-nan
# ..       ...      ...    ...         ...        ...        ...            ...
# 795      100      150     50           6       True       0.67     Rock-Fairy
# 796      160      110    110           6       True       1.45     Rock-Fairy
# 797      150      130     70           6       True       1.83  Psychic-Ghost
# 798      170      130     80           6       True       2.67   Psychic-Dark
# 799      130       90     70           6       True       0.92     Fire-Water
#
# [800 rows x 15 columns]

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
sorted(df['A/D_Ratio'].unique())[-5:]
# Out:
# [3.0, 3.12, 3.75, 4.5, 9.0]

# %%
# your code here
x=df.loc[df['A/D_Ratio'].sort_values(ascending=False).index][0:5]
x
# Out:
#        #                Name       t1      t2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock     NaN    350  67     125       40
# 428  386  DeoxysNormal Forme  Psychic     NaN    600  50     150       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D_Ratio   Combo_Type
# 429      180       20    150           3       True       9.00  Psychic-nan
# 347       65       20     65           3      False       4.50   Water-Dark
# 19        15       80    145           1      False       3.75   Bug-Poison
# 453       30       30     58           4      False       3.12     Rock-nan
# 428      150       50    150           3       True       3.00  Psychic-nan

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
# your code here
df[df.Combo_Type.isin(x.Combo_Type)].groupby('Combo_Type').mean()
# Out:
#                       #       Total         HP      Attack     Defense  \
# Combo_Type
# Bug-Poison   199.166667  347.916667  53.750000   68.333333   58.083333
# Psychic-nan  381.973684  464.552632  72.552632   64.947368   67.236842
# Rock-nan     410.111111  409.444444  67.111111  103.333333  107.222222
# Water-Dark   347.666667  493.833333  69.166667  120.000000   65.166667
#
#                Sp. Atk    Sp. Def      Speed  Generation  Legendary  A/D_Ratio
# Combo_Type
# Bug-Poison   42.500000  59.333333  65.916667    2.333333   0.000000   1.315833
# Psychic-nan  98.552632  82.394737  78.868421    3.342105   0.236842   1.164211
# Rock-nan     40.555556  58.333333  32.888889    3.888889   0.111111   1.258889
# Water-Dark   88.833333  63.500000  87.166667    3.166667   0.000000   2.291667

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
# your code here
